# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiArpit2006/Sai-Arpit-APS-LAB/blob/main/Lab_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 2. Divide and Conquer (Sorting)

# %% [markdown]
# - **Created by Dr. Ajay

# %% [markdown]
# Write a python program to perform **selection sort**.
# - ** -Algorithm
# * Step 1: Read the number of elements for the list from the user.
# * Step 2: Using for loop insert the elements in the list.
# * Step 3: Initialize the minimum element as min=numbers[i].
# * Step 4: Using the swap method the elements are sorted accordingly.
# * Step 5: Print the sorted list.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import random
import matplotlib.pyplot as plt

def selection_sort(arr):
    for i in range(len(arr)):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
sizes = [100, 200, 400, 600, 800, 1000]
times = []
for n in sizes:
    arr = [random.randint(1, 10000) for _ in range(n)]
    start_time = time.time()
    selection_sort(arr)
    end_time = time.time()
    times.append(end_time - start_time)
    print(f"Size {n} -> Time: {end_time - start_time:.5f} seconds")
plt.plot(sizes, times, marker='o')
plt.title("Selection Sort Running Time")
plt.xlabel("Array Size (n)")
plt.ylabel("Time (seconds)")
plt.grid(True)
plt.show()
# Out:
# Size 100 -> Time: 0.00064 seconds
# Size 200 -> Time: 0.00123 seconds
# Size 400 -> Time: 0.00443 seconds
# Size 600 -> Time: 0.00867 seconds
# Size 800 -> Time: 0.01603 seconds
# Size 1000 -> Time: 0.02495 seconds

# %% [markdown]
# In computer science, **merge sort** (also commonly spelled mergesort) is an efficient, general-purpose, comparison-based sorting algorithm. Most implementations produce a stable sort, which means that the order of equal elements is the same in the input and output. Merge sort is a divide and conquer algorithm that was invented by John von Neumann in 1945.
# Write a Python program to sort the elements using **merge sort** and plot a graph to the time taken versus n
# - Algorithm(Merge Sort is a divide and conquer algorithm. It divides	input array in two halve.s, calls itself for the two halves and then merges two sorted halves.)
# 1.	Divide the unsorted array into n partitions, each	partition contains 1 element.
# 2.	Repeatedly merge partitioned units to produce	new sublists until there is only l sublist remaining. This will be the sorted	.
# 3.	Compare the first element of the sublist with the first element of the sublist to its right.
# 4.	Merge the two sublists by	paring each element of the sublist and placing the smaller element into the	new sublist.
# 5.	Repeat step 3 and 4 untill	all sublists are merged into a single sorted sublist.

# %%
#write code for above cell and compute the running time and also plot graph.
import time
import matplotlib.pyplot as plt
import random
def merge_sort(arr):
  if len(arr) > 1:
    mid=len(arr)//2
    left=arr[:mid]
    right=arr[mid:]
    merge_sort(left)
    merge_sort(right)
    i=j=k=0
    while i<len(left) and j<len(right):
      if left[i]<=right[j]:
        arr[k]=left[i]
        i+=1
      else:
        arr[k]=right[j]
        j+=1
      k+=1
    while i<len(left):
      arr[k]=left[i]
      i+=1
      k+=1
    while j<len(right):
      arr[k]=right[j]
      j+=1
      k+=1
n=int(input("Enter number of elements: "))
arr=[]
for _ in range(n):
    arr.append(int(input()))
start=time.time()
merge_sort(arr)
end=time.time()
print("Sorted List:",arr)
print("Time taken:",end-start)
sizes=[]
times=[]
for size in range(100,1100,100):
    test_arr=random.sample(range(size*2),size)
    start=time.time()
    merge_sort(test_arr)
    end=time.time()
    sizes.append(size)
    times.append(end-start)
plt.plot(sizes,times,marker='o')
plt.xlabel("Number of Elements (n)")
plt.ylabel("Time (seconds)")
plt.title("Merge Sort Time Complexity")
plt.grid(True)
plt.show()
# Out:
# Enter number of elements: 5
# 1
# 2
# 3
# 4
# 5
# Sorted List: [1, 2, 3, 4, 5]
# Time taken: 9.250640869140625e-05

# %% [markdown]
# **Quicksort** (sometimes called partition-exchange sort) is an efficient sorting algorithm. Developed by British computer scientist Tony Hoare in 1959 and published in 1961, it is still a commonly used algorithm for sorting.
#
# Quicksort is a divide-and-conquer algorithm. It works by selecting a 'pivot' element from the array and partitioning the other elements into two sub-arrays, according to whether they are less than or greater than the pivot. The sub-arrays are then sorted recursively. This can be done in-place, requiring small additional amounts of memory to perform the sorting.
# Write a Python program to sort the elements using quick sort and plot a graph to the time taken versus n.
# - Algorithm
# 1.	Select a pivot element from the array.
# 2.	Partition the array into two sub-arrays. The elements in the first sub-array are less than the pivot element, while the elements in the second sub-array are greater than the pivot element.
# 3.	Recursively sort the sub-arrays created in Step 2.
# 4.	Join the sub-arrays and the pivot element together to	the sorted array.

# %%
#write code for above cell and compute the running time and also plot graph.
import random
import time
import matplotlib.pyplot as plt
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[-1]
    left = [x for x in arr[:-1] if x <= pivot]
    right = [x for x in arr[:-1] if x > pivot]
    return quick_sort(left) + [pivot] + quick_sort(right)
n_list = [100, 200, 400, 800, 1600]
numbers = [random.randint(1, 10000) for _ in range(max(n_list))]
times = []
for n in n_list:
    arr = numbers[:n]
    start = time.time()
    quick_sort(arr)
    end = time.time()
    times.append((end - start) * 1000)
plt.plot(n_list, times, marker='o')
plt.title("Quicksort: Time vs n")
plt.xlabel("Number of elements (n)")
plt.ylabel("Time (ms)")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Experiment: compare sorting algorithms

# %%
# Experiment variables
n_list = [1000, 2000, 5000, 10000, 20000, 50000, 100000, 200000]
n_max = n_list[len(n_list) -1]

# %%
# Creating a random value (uniform)
import datetime
import random
n_namx=10
ms = datetime.datetime.now().microsecond / 1000
random.seed(ms)
numbers = []
for i in range(n_max):
    numbers.append(int(random.random() * 1000))
print(numbers)
# Out:
# [517, 414, 233, 735, 688, 491, 268, 972, 34, 569, 20, 853, 953, 465, 537, 209, 449, 648, 145, 919, 158, 368, 737, 885, 896, 70, 143, 621, 985, 17, 610, 992, 727, 767, 469, 480, 492, 791, 999, 246, 114, 816, 499, 76, 397, 227, 513, 804, 380, 413, 191, 884, 943, 160, 258, 369, 121, 413, 553, 383, 549, 494, 998, 321, 825, 786, 287, 302, 464, 396, 973, 911, 525, 105, 484, 20, 341, 332, 828, 537, 817, 673, 555, 776, 135, 424, 722, 591, 950, 486, 716, 394, 276, 968, 429, 677, 926, 437, 461, 489, 444, 889, 471, 771, 255, 555, 349, 169, 36
625, 552, 245, 460, 793, 657, 363, 482, 337, 224, 771, 988, 458, 632, 422, 341, 20, 348, 245, 360, 33, 741, 675, 369, 473, 527, 36, 100, 262, 643, 27, 43, 58, 412, 248, 865, 710, 417, 409, 842, 771, 39, 837, 822, 356, 169, 269, 401, 433, 669, 724, 884, 141, 403, 212, 679, 759, 929, 892, 849, 411, 358, 925, 129, 671, 754, 329, 803, 210, 705, 893, 179, 583, 919, 671, 561, 932, 528, 348, 249, 839, 100, 869, 541, 61, 215, 750, 184, 473, 875, 130, 178, 359, 927, 875, 267, 633, 591, 912, 361, 23, 599, 501, 554, 451, 878, 164, 598, 950, 138, 282, 606, 370, 437, 490, 266, 638, 96, 569, 772, 873, 214, 231, 677, 622, 230, 753, 55, 837, 448, 75, 321, 885, 281, 2, 252, 299, 834, 177, 563, 39, 217, 833, 361, 972, 311, 527, 96, 995, 380, 473, 520, 355, 295, 180, 162, 73, 724, 732, 599, 269, 294, 946, 873, 889, 353, 365, 481, 696, 798, 270, 650, 434, 567, 836, 852, 521, 584, 775, 654, 637, 588, 807, 356, 817, 316, 691, 628, 764, 74, 788, 86, 944, 810, 539, 542, 627, 550, 753, 732, 108, 576, 661, 128, 889, 50, 311, 537, 116, 265, 693, 213, 356, 728, 286, 373, 381, 364, 859, 56, 774, 466, 578, 107, 304, 344, 797,  ...

# %%
import copy
import timeit

a_time = []
b_time = []
c_time = []

for l in n_list:
    a = copy.deepcopy(numbers[0:l])
    b = copy.deepcopy(numbers[0:l])
    c = copy.deepcopy(numbers[0:l])

    start_time = timeit.default_timer()
    quick_sort(a, 0, len(a) - 1)
    a_time.append((timeit.default_timer() - start_time) * 1000)


    start_time = timeit.default_timer()
    merge_sort(b)
    b_time.append((timeit.default_timer() - start_time) * 1000)

    if l <= 5000:
        start_time = timeit.default_timer()
        selection_sort(c)
        c_time.append((timeit.default_timer() - start_time) * 1000)
    else:
        c_time.append(None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3680175822.py in <cell line: 0>()
#      16
#      17     start_time = timeit.default_timer()
# ---> 18     merge_sort(b)
#      19     b_time.append((timeit.default_timer() - start_time) * 1000)
#      20
#
# NameError: name 'merge_sort' is not defined

# %%
# Plotting results
import matplotlib.pyplot as plt
import numpy as np

a_time_clean = [t if t is not None else 0 for t in a_time]
b_time_clean = [t if t is not None else 0 for t in b_time]
c_time_clean = [t if t is not None else 0 for t in c_time]

plt.figure(figsize=(10, 5))
plt.plot(a_time_clean, linewidth=1, marker="o")
plt.plot(b_time_clean, linewidth=1, marker="o")
plt.plot(c_time_clean, linewidth=1, marker="o")
plt.xticks(np.arange(len(n_list)), n_list)
plt.title("Compare Sorting Algorithms", fontsize=14)
plt.ylabel("Time (ms)")
plt.xlabel("n")
plt.legend(["Quicksort", "Mergesort", "Selection sort"], loc="best")
plt.grid(True)
plt.show()
# Out:
# [0.0006499999471998308]
# []
# []
