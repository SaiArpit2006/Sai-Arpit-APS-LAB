# %% [markdown]
# <a href="https://colab.research.google.com/github/SaiArpit2006/Sai-Arpit-APS-LAB/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {node:float('inf')for node in graph}
    previous={node:None for node in graph}
    visited = []
    distances[start]=0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node
        if min_node is None:
          break

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor]=min_node

    return distances,previous
def get_path(previous,start,end):
  path=[]
  current=end
  while current:
    path.insert(0,current)
    current=previous[current]
  if path[0]==start:
    return path
  return []

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}
n=int(input("Number of nodes:"))
for _ in range(n):
  node=input("Node:")
  graph[node]={}
  m=int(input("Neighbours:"))
  for _ in range(m):
    nb=input("Neighbour:")
    w=int(input("Weight:"))
    graph[node][nb]=w
graph['E']={'D':6}
graph['F']={'E':2}
def show_path(prev, start, end):
    path = [end]
    while end in prev:
        end = prev[end]
        path.insert(0, end)
    return path
while True:
  start=input("\nStart node:")
  dist,prev=dijkstra(graph,start)
  for node in graph:
    if dist[node]==float('inf'):
      print(start,"to",node,"=No path")
    else:
     path = show_path(prev, start, node)

if path:
    print(start, "to", node, "=", dist[node], "| Path:", "->".join(path))
else:
    print(start, "to", node, "=", dist[node], "| Path: Not reachable")
ch=input("\nTry another source?(y/n):")
if ch!='y':
    break
# Out:
# Number of nodes:2
# Node:A
# Neighbours:2
# Neighbour:B
# Weight:4
# Neighbour:C
# Weight:2
# Node:B
# Neighbours:2
# Neighbour:A
# Weight:4
# Neighbour:D
# Weight:10
#
# Start node:A
# A to E =No path
# A to F =No path
#
# Start node:B
# B to E =No path
# B to F =No path
#
# Start node:C
# C to E =No path
# C to F =No path
#
# Start node:D
# D to E =No path
# D to F =No path
#
# Start node:E
# E to F =No path
#
# Start node:F
#
# Start node:G
# G to A =No path
# G to B =No path
# G to C =No path
# G to D =No path
# G to E =No path
# G to F =No path

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
